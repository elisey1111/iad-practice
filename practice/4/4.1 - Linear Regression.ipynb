# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([4.83951325, 4.60314656, 1.52630453, 2.13767453, 3.01685509,
#        0.72375789, 3.36186444, 3.1594879 , 2.76166044, 3.71836166,
#        3.50493723, 4.07203349, 1.41049891, 3.32970544, 0.42348956,
#        3.12899898, 1.75435954, 1.70371051, 0.39013897, 4.83986322,
#        3.01114958, 1.81018893, 1.53294466, 4.11123231, 0.79115091,
#        4.48131903, 1.25663449, 0.52814632, 2.07771828, 4.46743565,
#        2.72359225, 2.2503719 , 1.1761757 , 3.39829461, 0.43740724,
#        3.36448812, 4.34524131, 4.64340679, 1.10216499, 1.31464274,
#        3.60916488, 0.49492859, 0.02488695, 0.82132629, 1.33861455,
#        2.0888032 , 0.35339549, 3.60374581, 2.02791655, 2.57298023,
#        3.82161458, 1.70200452, 2.14816728, 1.67764677, 4.22644237,
#        2.90582165, 4.24686555, 2.57838551, 4.67702338, 0.74956895,
#        2.96034927, 4.46478026, 4.71897884, 0.39781453, 1.34950656,
#        4.61068334, 1.27363398, 2.95009306, 1.80593115, 1.40213497,
#        3.16272645, 0.17438934, 2.26890818, 4.67886313, 0.43350249,
#        0.81967085, 3.96252757, 3.04795346, 1.04070268, 0.34555359,
#        4.01339887, 3.20696203, 1.31852813, 2.67005988, 4.8765799 ,
#        4.16681044, 1.03739881, 4.06807975, 4.52782746, 4.29605135,
#        4.754528  , 3.31919467, 2.80932052, 1.83907145, 1.86735134,
#        0.13232871, 3.35970894, 2.1019428 , 4.57455099, 0.68021533])

# %%
X # array where each row is an array to
# Out:
# array([[4.83951325],
#        [4.60314656],
#        [1.52630453],
#        [2.13767453],
#        [3.01685509],
#        [0.72375789],
#        [3.36186444],
#        [3.1594879 ],
#        [2.76166044],
#        [3.71836166],
#        [3.50493723],
#        [4.07203349],
#        [1.41049891],
#        [3.32970544],
#        [0.42348956],
#        [3.12899898],
#        [1.75435954],
#        [1.70371051],
#        [0.39013897],
#        [4.83986322],
#        [3.01114958],
#        [1.81018893],
#        [1.53294466],
#        [4.11123231],
#        [0.79115091],
#        [4.48131903],
#        [1.25663449],
#        [0.52814632],
#        [2.07771828],
#        [4.46743565],
#        [2.72359225],
#        [2.2503719 ],
#        [1.1761757 ],
#        [3.39829461],
#        [0.43740724],
#        [3.36448812],
#        [4.34524131],
#        [4.64340679],
#        [1.10216499],
#        [1.31464274],
#        [3.60916488],
#        [0.49492859],
#        [0.02488695],
#        [0.82132629],
#        [1.33861455],
#        [2.0888032 ],
#        [0.35339549],
#        [3.60374581],
#        [2.02791655],
#        [2.57298023],
#        [3.82161458],
#        [1.70200452],
#        [2.14816728],
#        [1.67764677],
#        [4.22644237],
#        [2.90582165],
#        [4.24686555],
#        [2.57838551],
#        [4.67702338],
#        [0.74956895],
#        [2.96034927],
#        [4.46478026],
#        [4.71897884],
#        [0.39781453],
#        [1.34950656],
#        [4.61068334],
#        [1.27363398],
#        [2.95009306],
#        [1.80593115],
#        [1.40213497],
#        [3.16272645],
#        [0.17438934],
#        [2.26890818],
#        [4.67886313],
#        [0.43350249],
#        [0.81967085],
#        [3.96252757],
#        [3.04795346],
#        [1.04070268],
#        [0.34555359],
#        [4.01339887],
#        [3.20696203],
#        [1.31852813],
#        [2.67005988],
#        [4.8765799 ],
#        [4.16681044],
#        [1.03739881],
#        [4.06807975],
#        [4.52782746],
#        [4.29605135],
#        [4.754528  ],
#        [3.31919467],
#        [2.80932052],
#        [1.83907145],
#        [1.86735134],
#        [0.13232871],
#        [3.35970894],
#        [2.1019428 ],
#        [4.57455099],
#        [0.68021533]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(1.0195794121505688)

# %%
b_found
# Out:
# np.float64(2.97285607333752)
